# %%
from ipywidgets import interact
import numpy as np

from bokeh.io import push_notebook,show,output_notebook
from bokeh.plotting import figure
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
x=np.linspace(0,2*np.pi,2000)
y=np.sin(x)

# %%
p=figure(title='simple line',plot_height=300,plot_width=600,y_range=(-5,5))
r=p.line(x,y,color='#2222aa',line_width=3)

# %%
def update(f,w=1,A=1,phi=0):
    if f=='sin':func=np.sin
    elif f=='cos':func=np.cos
    elif f=='tan':func=np.np.tan
    r.data_source.data['y']=A*func(w*x+phi)
    push_notebook()

# %%
show(p,notebook_handle=True)
# Out:
#   <div class="bk-root" id="969f4110-8508-43e2-8edd-cd92af371072" data-root-id="1002"></div>
# <p><code>&lt;Bokeh Notebook handle for <strong>In[9]</strong>&gt;</code></p>

# %%
interact(update,f=['sin','cos','tan'],w=(0,100),A=(1,5),phi=(0,20,0.1))
# Out:
# interactive(children=(Dropdown(description='f', options=('sin', 'cos', 'tan'), value='sin'), IntSlider(value=1…
# <function __main__.update(f, w=1, A=1, phi=0)>
